# %% [markdown]
# ## Introduction:
#
# In Python, sampling with replacement can be implemented with random.random to choose a percentile rank, or random.choice to choose an element from a sequence. Sampling without replacement is provided by random sample.
#
# The numbers generated by random.random are supposed to be uniform between 0 and 1; that is, every value in the range should have the same probability.
#
# ### Ex.
# Generate 1000 numbers from random.random and plot their PMF and CDF.
#
# Can you tell whether they are uniform?
#
# You can read about the uniform distribution at http://wikipedia.org/wiki/Uniform_distribution_(discrete)

# %%
import numpy as np
import Pmf
import Cdf
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sample = np.random.random(1000)  ## this is my list 
sample[1:10]
# Out:
# array([ 0.40765221,  0.91603228,  0.65361586,  0.01506335,  0.82817158,
#         0.44100763,  0.81172832,  0.1879327 ,  0.3782354 ])

# %%
pmf = Pmf.MakePmfFromList(sample)

# %%
plt.plot(pmf.d.keys(), pmf.d.values())
plt.xlabel("Random numbers")
plt.ylabel("PMFs")

# %% [markdown]
# Uniform distribution .. all values have the probability of 0.001

# %%
cdf = Cdf.MakeCdfFromList(sample)

# %%
plt.plot(cdf.xs, cdf.ps)
plt.xlabel("Random numbers")
plt.ylabel("CDFs")

# %% [markdown]
# It is harder to demonestrate the distribution using cdf ..
#
# as the idea of cdf is to add the probability of each data point (0.001) commulitevly .. hence, the sum of all these probs is 1
